# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
#  ![2-title.png](attachment:e24b0b8c-b223-4789-8d18-e546b1c454f3.png)

# %% [markdown]
# In this notebook I will summarize Data science tools and resources for future reference.

# %% [markdown]
# ![3-intro.png](attachment:cb5c65e4-7aff-4243-a114-8a17410f21b5.png)

# %% [markdown]
# #### Objectives:
# + The most popular languages
# + Most popular libraries
# + Data-Science-Tools
# + Arithmic operations

# %% [markdown]
# First, the most popular languages used in data science are:
# 1. Python
# 2. R
# 3. SQL
# 4. Java
# 5. c++
# 6. Javascript
# 7. Julia

# %% [markdown]
# ![4-dslanguages.png](attachment:6f43c27e-922c-4680-827c-3b22028778a0.png)

# %% [markdown]
# Second, Some of the libraries used are :
# 1. NumPy
# 2. Pandas
# 3. Matplotlib
# 4. Seaborn
# 5. Scikit-Learn

# %% [markdown]
# ![5-dslibraries.png](attachment:55cd5b40-0735-4490-ace3-3903a883dbdd.png)

# %% [markdown]
# # Data science tools

# %% [markdown]
# ![6-dstools.png](attachment:ec62540d-16d2-4623-bd93-1f91da347cbe.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
#  ![7-introarithmetic.png](attachment:1b029956-0179-43d1-87d6-08ef9598e0cf.png)

# %%
# this is a simple arithmic operation 
(3*4)+5
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:22550e3e-6ac4-4ea8-9891-c6020ac655c7.png)

# %%
#  This will convert 200 minutes to hours by dividing by 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ![9-hourstominutes.png](attachment:8d22def5-bb89-4f5a-88f8-bb02d35c5149.png)

# %% [markdown]
# ![10-objectives.png](attachment:4b996808-bc53-446a-8996-b5e6432a0178.png)

# %% [markdown]
# ## Author
# Nermine R

# %% [markdown]
# ![11-authordetails.png](attachment:7281eb37-d79b-41b0-96f3-db1470d28606.png)
